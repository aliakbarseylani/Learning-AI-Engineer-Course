# %%
import pandas as pd

# %%
coffee = pd.read_csv ('C:\\Users\\Aliakbar\\Desktop\\pandas\\DataSets\\coffee.csv')

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 468.0+ bytes

# %%
coffee.tail(10)
# Out:
#           Day Coffee Type  Units Sold
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.sample(5)
# Out:
#          Day Coffee Type  Units Sold
# 1     Monday       Latte          15
# 3    Tuesday       Latte          20
# 6   Thursday    Espresso          40
# 9     Friday       Latte          35
# 12    Sunday    Espresso          45

# %%
coffee.describe()
# Out:
#        Units Sold
# count   14.000000
# mean    32.857143
# std      9.346798
# min     15.000000
# 25%     26.250000
# 50%     35.000000
# 75%     38.750000
# max     45.000000

# %%
coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee.loc[[0, 6, 9]]
# Out:
#         Day Coffee Type  Units Sold
# 0    Monday    Espresso          25
# 6  Thursday    Espresso          40
# 9    Friday       Latte          35

# %%
coffee.loc[5:9, ["Day", "Units Sold"]]
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30
# 8     Friday          45
# 9     Friday          35

# %%
coffee.iloc[:, [0, 2]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
coffee.index = coffee["Day"]

# %%
coffee.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35

# %%
coffee.loc["Monday":"Tuesday"]
# Out:
#              Day Coffee Type  Units Sold
# Day
# Monday    Monday    Espresso          25
# Monday    Monday       Latte          15
# Tuesday  Tuesday    Espresso          30
# Tuesday  Tuesday       Latte          20

# %%
coffee_2 = pd.read_csv ('C:\\Users\\Aliakbar\\Desktop\\pandas\\DataSets\\coffee.csv')

# %%
coffee_2
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee_2.loc[1:3, "Units Sold"] = 10

# %%
coffee_2
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee_2.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee_2[["Day"]]
# Out:
#           Day
# 0      Monday
# 1      Monday
# 2     Tuesday
# 3     Tuesday
# 4   Wednesday
# 5   Wednesday
# 6    Thursday
# 7    Thursday
# 8      Friday
# 9      Friday
# 10   Saturday
# 11   Saturday
# 12     Sunday
# 13     Sunday

# %%
coffee_2.sort_values(["Units Sold"], ascending = False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10

# %%
coffee_2.sort_values(["Coffee Type"])
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 2     Tuesday    Espresso          10
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35

# %%
coffee_2.sort_values(["Units Sold", "Coffee Type"])
# Out:
#           Day Coffee Type  Units Sold
# 2     Tuesday    Espresso          10
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
bios = pd.read_csv ('C:\\Users\\Aliakbar\\Desktop\\pandas\\DataSets\\bios.csv')

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios.loc[bios["height_cm"]>215]
# Out:
#         athlete_id                   name   born_date               born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19         Moskva (Moscow)
# 5583          5606   Paulinho Villas Boas  1963-01-26               São Paulo
# 5673          5696         Gunther Behnke  1963-01-19              Leverkusen
# 5716          5739               Uwe Blab  1962-03-26        München (Munich)
# 5781          5804         Tommy Burleson  1952-02-24               Crossnore
# 5796          5819          Andy Campbell  1956-07-21               Melbourne
# 6223          6250            Lars Hansen  1954-09-27  København (Copenhagen)
# 6270          6298            Hu Zhangbao  1963-04-05                     NaN
# 6409          6440       Sergey Kovalenko  1947-08-11                     NaN
# 6420          6451          Jānis Krūmiņš  1930-01-30                   Cēsis
# 6504          6537            Luc Longley  1969-01-19               Melbourne
# ...

# %%
bios.loc[bios["height_cm"]>215,["name", "born_country", "height_cm"]]
# Out:
#                          name born_country  height_cm
# 5089       Viktor Pankrashkin          RUS      220.0
# 5583     Paulinho Villas Boas          BRA      217.0
# 5673           Gunther Behnke          GER      221.0
# 5716                 Uwe Blab          GER      218.0
# 5781           Tommy Burleson          USA      223.0
# 5796            Andy Campbell          AUS      218.0
# 6223              Lars Hansen          DEN      216.0
# 6270              Hu Zhangbao          NaN      216.0
# 6409         Sergey Kovalenko          NaN      216.0
# 6420            Jānis Krūmiņš          LAT      218.0
# 6504              Luc Longley          AUS      220.0
# 6722         Shaquille O'Neal          USA      216.0
# 6937           David Robinson          USA      216.0
# 6978          Arvydas Sabonis          LTU      223.0
# 7074           Paulo da Silva          BRA      217.0
# 7188       Vladimir Tkachenko          RUS      220.0
# ...

# %%
bios[bios["height_cm"]>215][["name", "born_country", "height_cm"]]
# Out:
#                          name born_country  height_cm
# 5089       Viktor Pankrashkin          RUS      220.0
# 5583     Paulinho Villas Boas          BRA      217.0
# 5673           Gunther Behnke          GER      221.0
# 5716                 Uwe Blab          GER      218.0
# 5781           Tommy Burleson          USA      223.0
# 5796            Andy Campbell          AUS      218.0
# 6223              Lars Hansen          DEN      216.0
# 6270              Hu Zhangbao          NaN      216.0
# 6409         Sergey Kovalenko          NaN      216.0
# 6420            Jānis Krūmiņš          LAT      218.0
# 6504              Luc Longley          AUS      220.0
# 6722         Shaquille O'Neal          USA      216.0
# 6937           David Robinson          USA      216.0
# 6978          Arvydas Sabonis          LTU      223.0
# 7074           Paulo da Silva          BRA      217.0
# 7188       Vladimir Tkachenko          RUS      220.0
# ...

# %%
bios[(bios["height_cm"]>215)&(bios["born_country"]=='IRI')]
# Out:
#         athlete_id           name   born_date born_city born_region  \
# 112337      113593  Hamed Haddadi  1985-05-19     Ahvaz   Khuzestan
#
#        born_country                       NOC  height_cm  weight_kg died_date
# 112337          IRI  Islamic Republic of Iran      218.0      110.0       NaN

# %%
bios[(bios["height_cm"]>215)|(bios["born_country"]=='IRI')]
# Out:
#         athlete_id                    name   born_date         born_city  \
# 3887          3900          Emanoul Aghasi  1930-12-25            Salmas
# 3888          3901           Nasser Aghaie  1944-01-20            Tehran
# 3901          3914         Ayoub Pourtaghi  1973-01-01  Orumiyeh (Urmia)
# 3905          3918         Vazik Ghazarian  1937-05-04        Bahmanshir
# 3907          3920        Iraj Kia Rostami  1963-07-07            Tehran
# ...            ...                     ...         ...               ...
# 140331      143837          Morteza Ghiasi  1995-04-07             Dorud
# 140332      143838    Mostafa Hosseinkhani  1989-03-27            Tehran
# 140333      143839               Reza Atri  1994-08-08             Babol
# 144049      147714        Mohammad Fotouhi  1990-12-05              Yazd
# 145469      149196  Danyal Saveh Shemshaki  1997-07-02            Tehran
#
#               born_region born_country                       NOC  height_cm  \
# ...

# %%
coffee_2['new_Price']=0

# %%
coffee_2['new_price_2']=(coffee_2['Units Sold']/2)*5

# %%
coffee_2
# Out:
#           Day Coffee Type  Units Sold  new_Price  new_price_2
# 0      Monday    Espresso          25          0         62.5
# 1      Monday       Latte          15          0         37.5
# 2     Tuesday    Espresso          30          0         75.0
# 3     Tuesday       Latte          20          0         50.0
# 4   Wednesday    Espresso          35          0         87.5
# 5   Wednesday       Latte          25          0         62.5
# 6    Thursday    Espresso          40          0        100.0
# 7    Thursday       Latte          30          0         75.0
# 8      Friday    Espresso          45          0        112.5
# 9      Friday       Latte          35          0         87.5
# 10   Saturday    Espresso          45          0        112.5
# 11   Saturday       Latte          35          0         87.5
# 12     Sunday    Espresso          45          0        112.5
# 13     Sunday       Latte          35          0         87.5

# %%
# coffee_3 = coffee_2.drop(columns=['new_price'])

# %%
# coffee_3

# %%
coffee_2.drop(columns=["new_Price"], inplace=True)

# %%
coffee_2['income'] = coffee_2['Units Sold'] * coffee_2['new_price_2']

# %%
coffee_2
# Out:
#           Day Coffee Type  Units Sold  new_price_2  income
# 0      Monday    Espresso          25         62.5  1562.5
# 1      Monday       Latte          15         37.5   562.5
# 2     Tuesday    Espresso          30         75.0  2250.0
# 3     Tuesday       Latte          20         50.0  1000.0
# 4   Wednesday    Espresso          35         87.5  3062.5
# 5   Wednesday       Latte          25         62.5  1562.5
# 6    Thursday    Espresso          40        100.0  4000.0
# 7    Thursday       Latte          30         75.0  2250.0
# 8      Friday    Espresso          45        112.5  5062.5
# 9      Friday       Latte          35         87.5  3062.5
# 10   Saturday    Espresso          45        112.5  5062.5
# 11   Saturday       Latte          35         87.5  3062.5
# 12     Sunday    Espresso          45        112.5  5062.5
# 13     Sunday       Latte          35         87.5  3062.5

# %%
coffee_2.rename(columns={'new_price_2':'price'}, inplace=True)

# %%
coffee_2
# Out:
#           Day Coffee Type  Units Sold  price  income
# 0      Monday    Espresso          25   62.5  1562.5
# 1      Monday       Latte          15   37.5   562.5
# 2     Tuesday    Espresso          30   75.0  2250.0
# 3     Tuesday       Latte          20   50.0  1000.0
# 4   Wednesday    Espresso          35   87.5  3062.5
# 5   Wednesday       Latte          25   62.5  1562.5
# 6    Thursday    Espresso          40  100.0  4000.0
# 7    Thursday       Latte          30   75.0  2250.0
# 8      Friday    Espresso          45  112.5  5062.5
# 9      Friday       Latte          35   87.5  3062.5
# 10   Saturday    Espresso          45  112.5  5062.5
# 11   Saturday       Latte          35   87.5  3062.5
# 12     Sunday    Espresso          45  112.5  5062.5
# 13     Sunday       Latte          35   87.5  3062.5

# %%
import numpy as np
coffee_2.loc[[2, 3], 'Units Sold']=np.nan

# %%
coffee_2
# Out:
#           Day Coffee Type  Units Sold  price  income
# 0      Monday    Espresso        25.0   62.5  1562.5
# 1      Monday       Latte        15.0   37.5   562.5
# 2     Tuesday    Espresso         NaN   75.0  2250.0
# 3     Tuesday       Latte         NaN   50.0  1000.0
# 4   Wednesday    Espresso        35.0   87.5  3062.5
# 5   Wednesday       Latte        25.0   62.5  1562.5
# 6    Thursday    Espresso        40.0  100.0  4000.0
# 7    Thursday       Latte        30.0   75.0  2250.0
# 8      Friday    Espresso        45.0  112.5  5062.5
# 9      Friday       Latte        35.0   87.5  3062.5
# 10   Saturday    Espresso        45.0  112.5  5062.5
# 11   Saturday       Latte        35.0   87.5  3062.5
# 12     Sunday    Espresso        45.0  112.5  5062.5
# 13     Sunday       Latte        35.0   87.5  3062.5

# %%
coffee_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   12 non-null     float64
#  3   price        14 non-null     float64
#  4   income       14 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 692.0+ bytes

# %%
coffee_2['Units Sold'].fillna(coffee_2['Units Sold'].mean())
# Out:
# 0     25.000000
# 1     15.000000
# 2     34.166667
# 3     34.166667
# 4     35.000000
# 5     25.000000
# 6     40.000000
# 7     30.000000
# 8     45.000000
# 9     35.000000
# 10    45.000000
# 11    35.000000
# 12    45.000000
# 13    35.000000
# Name: Units Sold, dtype: float64

# %% [markdown]
# ## The End
