# %%
import os 
os.chdir(r"C:\Users\Ahromeroshd\Desktop\01_Python")
print (os.getcwd())
# Out:
# C:\Users\Ahromeroshd\Desktop\01_Python

# %%
from IPython.display import Image
Image(filename='basics_topic.png', width="500")

# %%
Image(filename='Print_text.png', width="500")

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Definition a Variable, initialize and print.

# %%
name = "Aliakbar"
print(name)
# Out:
# Aliakbar

# %% [markdown]
# ## print a variable and a text with together in output.

# %%
# image resolution is X!
name = "Aliakbar"
print("Your first name is :", name)
# Out:
# Your first name is : Aliakbar

# %%
# Sensor / measuring temperature : temperature

temp = 43
print ('temprature is :' , temp)
# Out:
# temprature is : 43

# %% [markdown]
# ## Definition two variables the same name, initialize and print.

# %%
age = 23 
age = 34
print(age)
# Out:
# 34

# %% [markdown]
# ## initialize a few variables simultaneously. (with difference values)

# %%
name_1, name_2, name_3 = 'Aliakbar', 'Mahmoud', 'Hossein'
print(name_1)
print(name_2)
print(name_3)
# Out:
# Aliakbar
# Mahmoud
# Hossein

# %% [markdown]
# ## initialize a few variables simultaneously. (With same values)

# %%
family_1 = family_2 = family_3 = 'Seylani'
print(family_1)
print(family_2)
print(family_3)
# Out:
# Seylani
# Seylani
# Seylani

# %%
family_1 = 'Rostami'
print(family_1)
print(family_2)
print(family_3)
# Out:
# Rostami
# Seylani
# Seylani

# %%
print(id(family_1))
print(id(family_2))
print(id(family_3))
# Out:
# 2350721576480
# 2350722578448
# 2350722578448

# %% [markdown]
# ## initialize a few variables simultaneously by a list.

# %%
lst = [10, 20, 30]
a, b, c = lst
print('first item: ', a)
print('second item:', b)
print('third item: ',   c)
# Out:
# first item:  10
# second item: 20
# third item:  30

# %% [markdown]
# ## do we allow set any name on variables in python?

# %%
age = 25
age
# Out:
# 25

# %%
2age = 2 * age
age
# Out:
#   Cell In[48], line 1
#     2age = 2 * age
#     ^
# SyntaxError: invalid decimal literal

# %%
#Allowed!
#a-z
#A-Z
#_

# %%
#Not Allowed
#0_9
#Reserved: if else, space, return, True, False, None, ...
#%, #, @, %, and Special Symbols

# %%
فایل = 'this a test, you can definition persian variables '

# %%
print(فایل)
# Out:
# this a test, you can definition persian variables

# %%
last name = 'Seylani' #Error because used of space
# Out:
#   Cell In[82], line 1
#     last name = 'Seylani' #Error because used of space
#          ^
# SyntaxError: invalid syntax

# %%
# %address = 'Tehran'
# Out:
# UsageError: Line magic function `%address` not found.

# %% [markdown]
# ## data types in python.

# %%
## int ---> Sahih ---> 1, -1, -5
## float ---> Ashari ---> 0.5, 1.5, -0.35
## srt ---> Reshteh, String ---> 'Text', 'my name is Ali'
## bool ---> True, False
## list ---> [1, 2, 3]
## tuple ---> (1, 2, 3)
## dict ---> {"name": "Aliakbar", "family": "Seylani"}
## set ---> {1, 2, 3}

# %%
a = 10
b = 3.14
c = "laptop"
e = True
f = [1, 2, 3]
g = (4, 5, 6)
h = {"name": "Aliakbar", "family": "Seylani"}
i = {1, 2, 3}

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
print(type(c))
# Out:
# <class 'str'>

# %%
print(type(e))
# Out:
# <class 'bool'>

# %%
print(type(f))
# Out:
# <class 'list'>

# %%
print(type(g))
# Out:
# <class 'tuple'>

# %%
print(type(h))
# Out:
# <class 'dict'>

# %%
print(type(i))
# Out:
# <class 'set'>

# %%
v = 4j
print(type(v))
# Out:
# <class 'complex'>

# %%
b = None
print(type(b))
# Out:
# <class 'NoneType'>

# %%
lst2 = []
print(type(lst2))
# Out:
# <class 'list'>

# %%
print('do') #this command must have error but runs without error
# Out:
# do
